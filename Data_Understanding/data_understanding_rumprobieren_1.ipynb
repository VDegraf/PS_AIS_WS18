# %% [markdown]
# # Datenverständnis

# %% [markdown]
# In diesem Notebook werden unbereinigte Datensätze analysiert.
#
# Der Datensatz wird beschrieben und es werden Informationen wie die Sterneverteilung, durchschnittliche Bewertung und die durchschnittliche Anzahl der Bewertungen pro Artikel geliefert.

# %% [markdown]
# ### Import

# %%
import numpy as np
import pandas as pd
import gzip

# %% [markdown]
# ### Erzeugen eines Data Frames

# %%
def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

def data_understanding_1(path):
    return getDF(path)

# %% [markdown]
# #### Einlesen der Daten

# %% [markdown]
# *Die Variable "path" muss durch den Pfad der Datei ersetzt werden.*

# %%
df=getDF('../Data_raw/reviews_Musical_Instruments_5.json.gz')

# %% [markdown]
# ### Analyse des Data Frames

# %% [markdown]
# #### Sterneverteilung

# %%
df["overall"].value_counts().sort_index()
df["overall"].value_counts().index.tolist()
df["overall"].value_counts().to_frame()
k=df["overall"].value_counts(normalize=True).values.tolist()
print(k[0])
# Out:
# 0.6761524217912485

# %%
df.groupby("overall").count()
# Out:
#          reviewerID  asin  reviewerName  helpful  reviewText  summary  \
# overall
# 1.0             217   217           216      217         217      217
# 2.0             250   250           249      250         250      250
# 3.0             772   772           771      772         772      772
# 4.0            2084  2084          2080     2084        2084     2084
# 5.0            6938  6938          6918     6938        6938     6938
#
#          unixReviewTime  reviewTime
# overall
# 1.0                 217         217
# 2.0                 250         250
# 3.0                 772         772
# 4.0                2084        2084
# 5.0                6938        6938

# %% [markdown]
# #### Durchschnittliche Bewertungen pro Artikel

# %%
df["asin"].count()/(df["asin"].value_counts().count())
# Out:
# 11.401111111111112

# %% [markdown]
# #### Durchschnittliche Bewertung

# %%
df["overall"].sum()/df.shape[0]
# Out:
# 4.488743787155248

# %% [markdown]
# #### Median der Bewertungen

# %%
np.median(df["overall"])
# Out:
# 5.0

# %% [markdown]
# #### Anzahl Zeilen und Spalten

# %%
df.shape
# Out:
# (10261, 9)

# %% [markdown]
# #### Information der Daten

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10261 entries, 0 to 10260
# Data columns (total 9 columns):
# reviewerID        10261 non-null object
# asin              10261 non-null object
# reviewerName      10234 non-null object
# helpful           10261 non-null object
# reviewText        10261 non-null object
# overall           10261 non-null float64
# summary           10261 non-null object
# unixReviewTime    10261 non-null int64
# reviewTime        10261 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 801.6+ KB

# %% [markdown]
# #### Beschreibung der Daten

# %%
df.describe()
# Out:
#             overall  unixReviewTime
# count  10261.000000    1.026100e+04
# mean       4.488744    1.360606e+09
# std        0.894642    3.779735e+07
# min        1.000000    1.095466e+09
# 25%        4.000000    1.343434e+09
# 50%        5.000000    1.368490e+09
# 75%        5.000000    1.388966e+09
# max        5.000000    1.405987e+09

# %% [markdown]
# #### Auf Nullwerte überprüfen

# %%
df.isnull().sum()
# Out:
# reviewerID         0
# asin               0
# reviewerName      27
# helpful            0
# reviewText         0
# overall            0
# summary            0
# unixReviewTime     0
# reviewTime         0
# dtype: int64

# %% [markdown]
# #### Header der Daten

# %%
df.head()
# Out:
#        reviewerID        asin  \
# 0  A2IBPI20UZIR0U  1384719342
# 1  A14VAT5EAX3D9S  1384719342
# 2  A195EZSQDW3E21  1384719342
# 3  A2C00NNG1ZQQG2  1384719342
# 4   A94QU4C90B1AX  1384719342
#
#                                        reviewerName   helpful  \
# 0  cassandra tu "Yeah, well, that's just like, u...    [0, 0]
# 1                                              Jake  [13, 14]
# 2                     Rick Bennette "Rick Bennette"    [1, 1]
# 3                         RustyBill "Sunday Rocker"    [0, 0]
# 4                                     SEAN MASLANKA    [0, 0]
#
#                                           reviewText  overall  \
# 0  Not much to write about here, but it does exac...      5.0
# 1  The product does exactly as it should and is q...      5.0
# 2  The primary job of this device is to block the...      5.0
# 3  Nice windscreen protects my MXL mic and preven...      5.0
# 4  This pop filter is great. It looks and perform...      5.0
#
# ...

# %% [markdown]
# ### Zusammenfassende Funktion

# %%
import pandas as pd
import gzip
import numpy as np

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

def data_understanding_1(path,name):
    df = getDF(path)

    # Sterneverteilung
    a=df["overall"].value_counts().sort_index()
    
    #Median der Sterneverteilung
    d=np.median(df["overall"])

    # Durchschnittliche Anzahl Bewertungen pro Artikel
    b=df["asin"].count()/(df["asin"].value_counts().count())

    # Durchschnittliche Bewertung
    c=df["overall"].sum()/df.shape[0]
    
    #Anzahl der Artikel im Datensatz
    e=df["asin"].value_counts().count()
    
    f=df["overall"].value_counts(normalize=True).values.tolist()
    
    g=round(f[0])
    h=round(f[1])
    i=round(f[2])
    j=round(f[3])
    k=round(f[4])
    
    print("Auf Nullwerte überprüfen:")
    print()
    print(df.isnull().sum())

    data = {'Durchschnittliche Anzahl an Bewertungen': [b], "Durchschnittliche Bewertung": [c],"Median der Bewertung":[d],"Anzahl an Artikeln":[e],"Prozentualer Anteil 5-Sterne Bewertungen":[g],"Prozentualer Anteil 4-Sterne Bewertungen":[h],"Prozentualer Anteil 3-Sterne Bewertungen":[i],"Prozentualer Anteil 2-Sterne Bewertungen":[j],"Prozentualer Anteil 1-Sterne Bewertungen":[k]}
    df2 = pd.DataFrame(data=data)
    df2.to_csv("./data_rumprobieren/%s.csv" %name, sep=',',index=False)
    return df2

# %%
data_understanding_1('../Data_raw/reviews_Apps_for_Android_5.json.gz', "Apps_for_Android")

# %%
data_understanding_1('../Data_raw/reviews_Automotive_5.json.gz',"Auto")
# Out:
# Auf Nullwerte überprüfen:
#
# reviewerID          0
# asin                0
# reviewerName      213
# helpful             0
# reviewText          0
# overall             0
# summary             0
# unixReviewTime      0
# reviewTime          0
# dtype: int64
#    Durchschnittliche Anzahl an Bewertungen  Durchschnittliche Bewertung  \
# 0                                11.156948                     4.471841
#
#    Median der Bewertung  Anzahl an Artikeln  \
# 0                   5.0                1835
#
#    Prozentualer Anteil 5-Sterne Bewertungen  \
# 0                                  0.680311
#
#    Prozentualer Anteil 4-Sterne Bewertungen  \
# 0                                  0.193767
#
#    Prozentualer Anteil 3-Sterne Bewertungen  \
# 0                                  0.069848
#
#    Prozentualer Anteil 2-Sterne Bewertungen  \
# 0                                    0.0296
#
#    Prozentualer Anteil 1-Sterne Bewertungen
# 0                                  0.026474

# %%
data_understanding_1('../Data_raw/reviews_Baby_5.json.gz',"Baby")
# Out:
# Auf Nullwerte überprüfen:
#
# reviewerID           0
# asin                 0
# reviewerName      1365
# helpful              0
# reviewText           0
# overall              0
# summary              0
# unixReviewTime       0
# reviewTime           0
# dtype: int64
#    Durchschnittliche Anzahl an Bewertungen  Durchschnittliche Bewertung  \
# 0                                22.807376                     4.214115
#
#    Median der Bewertung  Anzahl an Artikeln  \
# 0                   5.0                7050
#
#    Prozentualer Anteil 5-Sterne Bewertungen  \
# 0                                  0.581658
#
#    Prozentualer Anteil 4-Sterne Bewertungen  \
# 0                                  0.205228
#
#    Prozentualer Anteil 3-Sterne Bewertungen  \
# 0                                  0.107313
#
#    Prozentualer Anteil 2-Sterne Bewertungen  \
# 0                                  0.057173
#
#    Prozentualer Anteil 1-Sterne Bewertungen
# 0                                  0.048628

# %%
data_understanding_1('../Data_raw/reviews_Beauty_5.json.gz',"Beauty")
# Out:
# Auf Nullwerte überprüfen:
#
# reviewerID           0
# asin                 0
# reviewerName      1386
# helpful              0
# reviewText           0
# overall              0
# summary              0
# unixReviewTime       0
# reviewTime           0
# dtype: int64
#    Durchschnittliche Anzahl an Bewertungen  Durchschnittliche Bewertung  \
# 0                                16.403768                     4.190391
#
#    Median der Bewertung  Anzahl an Artikeln  \
# 0                   5.0               12101
#
#    Prozentualer Anteil 5-Sterne Bewertungen  \
# 0                                  0.576977
#
#    Prozentualer Anteil 4-Sterne Bewertungen  \
# 0                                  0.200205
#
#    Prozentualer Anteil 3-Sterne Bewertungen  \
# 0                                  0.112079
#
#    Prozentualer Anteil 2-Sterne Bewertungen  \
# 0                                  0.057712
#
#    Prozentualer Anteil 1-Sterne Bewertungen
# 0                                  0.053027

# %%
data_understanding_1('../Data_raw/reviews_Books_5.json.gz',"Bücher")

# %%
data_understanding_1('../Data_raw/reviews_CDs_and_Vinyl_5.json.gz',"CD")

# %%
data_understanding_1('../Data_raw/reviews_Cell_Phones_and_Accessories_5.json',"Mobiltelefone")

# %%
data_understanding_1('../Data_raw/reviews_Clothing_Shoes_and_Jewelry_5.json.gz',"Bekleidung,Schuhe,Schmuck")

# %%
data_understanding_1('../Data_raw/reviews_Digital_Music_5.json.gz')

# %%
data_understanding_1('../Data_raw/reviews_Electronics_5.json.gz')
# Out:
# Durchschnittliche Anzahl Bewertungen pro Artikel:
#
# 26.81208234789924
#
#
# Sterneverteilung:
#
# 1.0     108725
# 2.0      82139
# 3.0     142257
# 4.0     347041
# 5.0    1009026
# Name: overall, dtype: int64
#
#
# Durchschnittliche Bewertung:
#
# 4.222779228836577
#
#
# Median der Bewertungen:
#
# 5.0
#
# Anzahl Zeilen und Spalten:
#
# (1689188, 9)
#
#
# Informationen der Daten:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1689188 entries, 0 to 1689187
# Data columns (total 9 columns):
# reviewerID        1689188 non-null object
# asin              1689188 non-null object
# reviewerName      1664458 non-null object
# helpful           1689188 non-null object
# reviewText        1689188 non-null object
# overall           1689188 non-null float64
# summary           1689188 non-null object
# unixReviewTime    1689188 non-null int64
# reviewTime        1689188 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 128.9+ MB
# None
#
#
# ...

# %%
data_understanding_1('../Data_raw/reviews_Health_and_Personal_Care_5.json.gz')
# Out:
# Durchschnittliche Anzahl Bewertungen pro Artikel:
#
# 18.687547210531996
#
#
# Sterneverteilung:
#
# 1.0     16546
# 2.0     16754
# 3.0     33254
# 4.0     68168
# 5.0    211633
# Name: overall, dtype: int64
#
#
# Durchschnittliche Bewertung:
#
# 4.274957774537685
#
#
# Median der Bewertungen:
#
# 5.0
#
# Anzahl Zeilen und Spalten:
#
# (346355, 9)
#
#
# Informationen der Daten:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 346355 entries, 0 to 346354
# Data columns (total 9 columns):
# reviewerID        346355 non-null object
# asin              346355 non-null object
# reviewerName      343304 non-null object
# helpful           346355 non-null object
# reviewText        346355 non-null object
# overall           346355 non-null float64
# summary           346355 non-null object
# unixReviewTime    346355 non-null int64
# reviewTime        346355 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 26.4+ MB
# None
#
#
# Beschreibung der Daten:
#
# ...

# %%
data_understanding_1('../Data_raw/reviews_Home_and_Kitchen_5.json.gz')
# Out:
# Durchschnittliche Anzahl Bewertungen pro Artikel:
#
# 19.53755710592485
#
#
# Sterneverteilung:
#
# 1.0     27106
# 2.0     24313
# 3.0     45059
# 4.0    105508
# 5.0    349696
# Name: overall, dtype: int64
#
#
# Durchschnittliche Bewertung:
#
# 4.316655247044493
#
#
# Median der Bewertungen:
#
# 5.0
#
# Anzahl Zeilen und Spalten:
#
# (551682, 9)
#
#
# Informationen der Daten:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 551682 entries, 0 to 551681
# Data columns (total 9 columns):
# reviewerID        551682 non-null object
# asin              551682 non-null object
# reviewerName      546729 non-null object
# helpful           551682 non-null object
# reviewText        551682 non-null object
# overall           551682 non-null float64
# summary           551682 non-null object
# unixReviewTime    551682 non-null int64
# reviewTime        551682 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 42.1+ MB
# None
#
#
# Beschreibung der Daten:
#
# ...

# %%
data_understanding_1('../Data_raw/reviews_Kindle_Store_5.json.gz')
# Out:
# Durchschnittliche Anzahl Bewertungen pro Artikel:
#
# 15.86558271708593
#
#
# Sterneverteilung:
#
# 5.0    575264
# 4.0    254013
# 3.0     96194
# 2.0     34130
# 1.0     23018
# Name: overall, dtype: int64
#
#
# Durchschnittliche Bewertung:
#
# 4.347801131466011
#
#
# Median der Bewertungen:
#
# 5.0
#
#
# Anzahl Zeilen und Spalten:
#
# (982619, 9)
#
#
# Informationen der Daten:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 982619 entries, 0 to 982618
# Data columns (total 9 columns):
# reviewerID        982619 non-null object
# asin              982619 non-null object
# reviewerName      978820 non-null object
# helpful           982619 non-null object
# reviewText        982619 non-null object
# overall           982619 non-null float64
# summary           982619 non-null object
# unixReviewTime    982619 non-null int64
# reviewTime        982619 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 75.0+ MB
# None
#
#
# Beschreibung der Daten:
#
# ...

# %%
data_understanding_1('../Data_raw/reviews_Movies_and_TV_5.json.gz')
# Out:
# Durchschnittliche Anzahl Bewertungen pro Artikel:
#
# 33.91538799648366
#
#
# Sterneverteilung:
#
# 5.0    906608
# 4.0    382994
# 3.0    201302
# 1.0    104219
# 2.0    102410
# Name: overall, dtype: int64
#
#
# Durchschnittliche Bewertung:
#
# 4.110648217148062
#
#
# Median der Bewertungen:
#
# 5.0
# 33.91538799648366
#
# Anzahl Zeilen und Spalten:
#
# (1697533, 9)
#
#
# Informationen der Daten:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1697533 entries, 0 to 1697532
# Data columns (total 9 columns):
# reviewerID        object
# asin              object
# reviewerName      object
# helpful           object
# reviewText        object
# overall           float64
# summary           object
# unixReviewTime    int64
# reviewTime        object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 129.5+ MB
# None
#
#
# Beschreibung der Daten:
#
#             overall  unixReviewTime
# count  1.697533e+06    1.697533e+06
# mean   4.110648e+00    1.262422e+09
# ...

# %%
data_understanding_1('../Data_raw/reviews_Musical_Instruments_5.json.gz')
# Out:
# Durchschnittliche Anzahl Bewertungen pro Artikel:
#
# 11.401111111111112
#
#
# Sterneverteilung:
#
# 5.0    6938
# 4.0    2084
# 3.0     772
# 2.0     250
# 1.0     217
# Name: overall, dtype: int64
#
#
# Durchschnittliche Bewertung:
#
# 4.488743787155248
#
#
# Median der Bewertungen:
#
# 5.0
#
#
# Anzahl Zeilen und Spalten:
#
# (10261, 9)
#
#
# Informationen der Daten:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10261 entries, 0 to 10260
# Data columns (total 9 columns):
# reviewerID        10261 non-null object
# asin              10261 non-null object
# reviewerName      10234 non-null object
# helpful           10261 non-null object
# reviewText        10261 non-null object
# overall           10261 non-null float64
# summary           10261 non-null object
# unixReviewTime    10261 non-null int64
# reviewTime        10261 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 801.6+ KB
# None
#
#
# Beschreibung der Daten:
#
# ...

# %%
data_understanding_1('../Data_raw/reviews_Office_Products_5.json.gz')
# Out:
# Durchschnittliche Anzahl Bewertungen pro Artikel:
#
# 22.007438016528926
#
#
# Sterneverteilung:
#
# 5.0    30327
# 4.0    15015
# 3.0     5060
# 2.0     1726
# 1.0     1130
# Name: overall, dtype: int64
#
#
# Durchschnittliche Bewertung:
#
# 4.345957414848473
#
#
# Median der Sterne:
#
# 5.0
#
#
# Anzahl Zeilen und Spalten:
#
# (53258, 9)
#
#
# Informationen der Daten:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53258 entries, 0 to 53257
# Data columns (total 9 columns):
# reviewerID        53258 non-null object
# asin              53258 non-null object
# reviewerName      52799 non-null object
# helpful           53258 non-null object
# reviewText        53258 non-null object
# overall           53258 non-null float64
# summary           53258 non-null object
# unixReviewTime    53258 non-null int64
# reviewTime        53258 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 4.1+ MB
# None
#
#
# Beschreibung der Daten:
#
# ...

# %%
print(df["asin"].value_counts().count())
# Out:
# 900

# %%
df2={}
