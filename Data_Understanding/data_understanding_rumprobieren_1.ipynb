# %% [markdown]
# # Datenverständnis

# %% [markdown]
# In diesem Notebook werden unbereinigte Datensätze analysiert.
#
# Der Datensatz wird beschrieben und es werden Informationen wie die Sterneverteilung, durchschnittliche Bewertung und die durchschnittliche Anzahl der Bewertungen pro Artikel geliefert.

# %% [markdown]
# ### Import

# %%
import numpy as np
import pandas as pd
import gzip

# %% [markdown]
# ### Erzeugen eines Data Frames

# %%
def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

def data_understanding_1(path):
    return getDF(path)

# %% [markdown]
# #### Einlesen der Daten

# %% [markdown]
# *Die Variable "path" muss durch den Pfad der Datei ersetzt werden.*

# %%
df=getDF('../Data_raw/reviews_Musical_Instruments_5.json.gz')

# %% [markdown]
# ### Analyse des Data Frames

# %% [markdown]
# #### Sterneverteilung

# %%
df["overall"].value_counts().sort_index()
df["overall"].value_counts().index.tolist()
df["overall"].value_counts().to_frame()
k=df["overall"].value_counts(normalize=True).values.tolist()
print(k[0])
# Out:
# 0.6761524217912485

# %%
df.groupby("overall").count()
# Out:
#          reviewerID  asin  reviewerName  helpful  reviewText  summary  \
# overall
# 1.0             217   217           216      217         217      217
# 2.0             250   250           249      250         250      250
# 3.0             772   772           771      772         772      772
# 4.0            2084  2084          2080     2084        2084     2084
# 5.0            6938  6938          6918     6938        6938     6938
#
#          unixReviewTime  reviewTime
# overall
# 1.0                 217         217
# 2.0                 250         250
# 3.0                 772         772
# 4.0                2084        2084
# 5.0                6938        6938

# %% [markdown]
# #### Durchschnittliche Bewertungen pro Artikel

# %%
df["asin"].count()/(df["asin"].value_counts().count())
# Out:
# 11.401111111111112

# %% [markdown]
# #### Durchschnittliche Bewertung

# %%
df["overall"].sum()/df.shape[0]
# Out:
# 4.488743787155248

# %% [markdown]
# #### Median der Bewertungen

# %%
np.median(df["overall"])
# Out:
# 5.0

# %% [markdown]
# #### Anzahl Zeilen und Spalten

# %%
df.shape
# Out:
# (10261, 9)

# %% [markdown]
# #### Information der Daten

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10261 entries, 0 to 10260
# Data columns (total 9 columns):
# reviewerID        10261 non-null object
# asin              10261 non-null object
# reviewerName      10234 non-null object
# helpful           10261 non-null object
# reviewText        10261 non-null object
# overall           10261 non-null float64
# summary           10261 non-null object
# unixReviewTime    10261 non-null int64
# reviewTime        10261 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 801.6+ KB

# %% [markdown]
# #### Beschreibung der Daten

# %%
df.describe()
# Out:
#             overall  unixReviewTime
# count  10261.000000    1.026100e+04
# mean       4.488744    1.360606e+09
# std        0.894642    3.779735e+07
# min        1.000000    1.095466e+09
# 25%        4.000000    1.343434e+09
# 50%        5.000000    1.368490e+09
# 75%        5.000000    1.388966e+09
# max        5.000000    1.405987e+09

# %% [markdown]
# #### Auf Nullwerte überprüfen

# %%
df.isnull().sum()
# Out:
# reviewerID         0
# asin               0
# reviewerName      27
# helpful            0
# reviewText         0
# overall            0
# summary            0
# unixReviewTime     0
# reviewTime         0
# dtype: int64

# %% [markdown]
# #### Header der Daten

# %%
df.head()
# Out:
#        reviewerID        asin  \
# 0  A2IBPI20UZIR0U  1384719342
# 1  A14VAT5EAX3D9S  1384719342
# 2  A195EZSQDW3E21  1384719342
# 3  A2C00NNG1ZQQG2  1384719342
# 4   A94QU4C90B1AX  1384719342
#
#                                        reviewerName   helpful  \
# 0  cassandra tu "Yeah, well, that's just like, u...    [0, 0]
# 1                                              Jake  [13, 14]
# 2                     Rick Bennette "Rick Bennette"    [1, 1]
# 3                         RustyBill "Sunday Rocker"    [0, 0]
# 4                                     SEAN MASLANKA    [0, 0]
#
#                                           reviewText  overall  \
# 0  Not much to write about here, but it does exac...      5.0
# 1  The product does exactly as it should and is q...      5.0
# 2  The primary job of this device is to block the...      5.0
# 3  Nice windscreen protects my MXL mic and preven...      5.0
# 4  This pop filter is great. It looks and perform...      5.0
#
#                                  summary  unixReviewTime   reviewTime
# 0                                   good      1393545600  02 28, 2014
# 1                                   Jake      1363392000  03 16, 2013
# 2                   It Does The Job Well      1377648000  08 28, 2013
# 3          GOOD WINDSCREEN FOR THE MONEY      1392336000  02 14, 2014
# 4  No more pops when I record my vocals.      1392940800  02 21, 2014

# %% [markdown]
# ### Zusammenfassende Funktion

# %%
import pandas as pd
import gzip
import numpy as np
import time
from tqdm import tqdm

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

def data_understanding_1():
    df3={}
    namelist=[]
    medianlist=[]
    average_counter_scorelist=[]
    average_scorelist=[]
    counter_articlelist=[]
    star1list=[]
    star2list=[]
    star3list=[]
    star4list=[]
    star5list=[]
    category = {
        #"books" : "reviews_Books_5.json.gz",
        #"electronics" : "reviews_Electronics_5.json.gz",
        #"movies_and_tv" : "reviews_Movies_and_TV_5.json.gz",
        #"cd_and_vinyl" : "reviews_CDs_and_Vinyl_5.json.gz",
        #"clothing_shoes_jewelry" : "reviews_Clothing_Shoes_and_Jewelry_5.json.gz",
        #"home_and_kitchen" : "reviews_Home_and_Kitchen_5.json.gz",
        #"kindle_store" : "reviews_Kindle_Store_5.json.gz",
        #"sports_and_outdoors" : "reviews_Sports_and_Outdoors_5.json.gz",
        #"cell_phones_and_accessories" : "reviews_Cell_Phones_and_Accessories_5.json.gz",
        #"health_and_personal_care" : "reviews_Health_and_Personal_Care_5.json.gz",
        #"toys_and_games" : "reviews_Toys_and_Games_5.json.gz",
        #"video_games" : "reviews_Video_Games_5.json.gz",
        #"tools_and_home_improvement" : "reviews_Tools_and_Home_Improvement_5.json.gz",
        #"beauty" : "reviews_Beauty_5.json.gz",
        #"apps_for_android" : "reviews_Apps_for_Android_5.json.gz",
        #"office_products" : "reviews_Office_Products_5.json.gz",
        #"pet_supplies" : "reviews_Pet_Supplies_5.json.gz",
        #"automotive" : "reviews_Automotive_5.json.gz",
        #"grocery_and_gourmet_food" : "reviews_Grocery_and_Gourmet_Food_5.json.gz",
        #"patio_lawn_and_garden" : "reviews_Patio_Lawn_and_Garden_5.json.gz",
        "baby" : "reviews_Baby_5.json.gz",
        "digital_music" : "reviews_Digital_Music_5.json.gz",
        "musical_instruments" : "reviews_Musical_Instruments_5.json.gz",
        "amazon_instant_video" : "reviews_Amazon_Instant_Video_5.json.gz" }
    
    print("Abgeschlossene Datensätze:")
    for i in tqdm(range(10)):
        
    for key in category:
        df = getDF("../Data_Raw/%s" %category[key])
        
        # Fortschrittsanzeige
        print(key)
        
        # Name des Datensatzes
        name = key
        
        # Median der Sterneverteilung
        median = np.median(df["overall"])

        # Durchschnittliche Anzahl Bewertungen pro Artikel
        average_counter_score= df["asin"].count()/(df["asin"].value_counts().count())

        # Durchschnittliche Bewertung
        average_score = df["overall"].sum()/df.shape[0]

        # Anzahl der Artikel im Datensatz
        counter_article = df["asin"].value_counts().count()

        # Sterneverteilung sortiert in Prozent
        e = df["overall"].value_counts(normalize=True).sort_index().values.tolist()

        # Prozentualer Anteil 1-Sterne Bewertungen
        star1 = round(e[0],2)

        # Prozentualer Anteil 2-Sterne Bewertungen
        star2 = round(e[1],2)

        # Prozentualer Anteil 3-Sterne Bewertungen
        star3 = round(e[2],2)

        # Prozentualer Anteil 4-Sterne Bewertungen
        star4 = round(e[3],2)

        # Prozentualer Anteil 5-Sterne Bewertungen
        star5 = round(e[4],2)
        
        namelist.append(name)
        medianlist.append(median)
        average_counter_scorelist.append(average_counter_score)
        average_scorelist.append(average_score)
        counter_articlelist.append(counter_article)
        star1list.append(star1)
        star2list.append(star2)
        star3list.append(star3)
        star4list.append(star4)
        star5list.append(star5)
    
    # Erzeugen eines DataFrames
    data = {"Datensatz": namelist,'Durchschnittliche Anzahl an Bewertungen pro Artikel': average_counter_scorelist, "Durchschnittliche Bewertung": average_scorelist, "Median der Bewertung":medianlist, "Anzahl an Artikeln":counter_articlelist, "Prozentualer Anteil 5-Sterne Bewertungen":star5list, "Prozentualer Anteil 4-Sterne Bewertungen":star4list, "Prozentualer Anteil 3-Sterne Bewertungen":star3list, "Prozentualer Anteil 2-Sterne Bewertungen": star2list , "Prozentualer Anteil 1-Sterne Bewertungen":star1list}
    df2 = pd.DataFrame(data=data)

    # Export in CSV Datei
    df2.to_csv("Data_understanding_csv/all_reviews.csv", sep=',',index=False) #%category[key], sep=',',index=False)
    
    # Darstellung in einer Tabelle
    return df2

# %%
data_understanding_1()
# Out:
# Abgeschlossene Datensätze:
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]
# baby
# digital_music
# musical_instruments
# amazon_instant_video
#  10%|████████▎                                                                          | 1/10 [00:20<03:05, 20.58s/it]
# baby
# digital_music
# musical_instruments
# amazon_instant_video
#  20%|████████████████▌                                                                  | 2/10 [00:41<02:45, 20.67s/it]
# baby
# digital_music
# musical_instruments
# amazon_instant_video
#  30%|████████████████████████▉                                                          | 3/10 [01:02<02:24, 20.67s/it]
# baby
# digital_music
# musical_instruments
# amazon_instant_video
#  40%|█████████████████████████████████▏                                                 | 4/10 [01:22<02:03, 20.59s/it]
# baby
# digital_music
# musical_instruments
# amazon_instant_video
#  50%|█████████████████████████████████████████▌                                         | 5/10 [01:43<01:44, 20.85s/it]
# baby
# digital_music
# musical_instruments
# amazon_instant_video
#  60%|█████████████████████████████████████████████████▊                                 | 6/10 [02:04<01:23, 20.76s/it]
# baby
# digital_music
# musical_instruments
# amazon_instant_video
#  70%|██████████████████████████████████████████████████████████                         | 7/10 [02:24<01:01, 20.66s/it]
# baby
# digital_music
# musical_instruments
# amazon_instant_video
#  80%|██████████████████████████████████████████████████████████████████▍                | 8/10 [02:50<00:43, 21.99s/it]
# baby
# digital_music
# musical_instruments
# amazon_instant_video
#  90%|██████████████████████████████████████████████████████████████████████████▋        | 9/10 [03:12<00:22, 22.13s/it]
# baby
# digital_music
# musical_instruments
# amazon_instant_video
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:33<00:00, 21.93s/it]
#                Datensatz  Durchschnittliche Anzahl an Bewertungen pro Artikel  \
# 0                   baby                                          22.807376
# 1          digital_music                                          18.135090
# 2    musical_instruments                                          11.401111
# 3   amazon_instant_video                                          22.033234
# 4                   baby                                          22.807376
# 5          digital_music                                          18.135090
# 6    musical_instruments                                          11.401111
# 7   amazon_instant_video                                          22.033234
# 8                   baby                                          22.807376
# 9          digital_music                                          18.135090
# 10   musical_instruments                                          11.401111
# 11  amazon_instant_video                                          22.033234
# 12                  baby                                          22.807376
# 13         digital_music                                          18.135090
# 14   musical_instruments                                          11.401111
# 15  amazon_instant_video                                          22.033234
# 16                  baby                                          22.807376
# 17         digital_music                                          18.135090
# 18   musical_instruments                                          11.401111
# 19  amazon_instant_video                                          22.033234
# 20                  baby                                          22.807376
# 21         digital_music                                          18.135090
# 22   musical_instruments                                          11.401111
# 23  amazon_instant_video                                          22.033234
# 24                  baby                                          22.807376
# 25         digital_music                                          18.135090
# 26   musical_instruments                                          11.401111
# 27  amazon_instant_video                                          22.033234
# 28                  baby                                          22.807376
# 29         digital_music                                          18.135090
# 30   musical_instruments                                          11.401111
# 31  amazon_instant_video                                          22.033234
# 32                  baby                                          22.807376
# 33         digital_music                                          18.135090
# 34   musical_instruments                                          11.401111
# 35  amazon_instant_video                                          22.033234
# 36                  baby                                          22.807376
# 37         digital_music                                          18.135090
# 38   musical_instruments                                          11.401111
# 39  amazon_instant_video                                          22.033234
#
#     Durchschnittliche Bewertung  Median der Bewertung  Anzahl an Artikeln  \
# 0                      4.214115                   5.0                7050
# 1                      4.222514                   5.0                3568
# 2                      4.488744                   5.0                 900
# 3                      4.209530                   5.0                1685
# 4                      4.214115                   5.0                7050
# 5                      4.222514                   5.0                3568
# 6                      4.488744                   5.0                 900
# 7                      4.209530                   5.0                1685
# 8                      4.214115                   5.0                7050
# 9                      4.222514                   5.0                3568
# 10                     4.488744                   5.0                 900
# 11                     4.209530                   5.0                1685
# 12                     4.214115                   5.0                7050
# 13                     4.222514                   5.0                3568
# 14                     4.488744                   5.0                 900
# 15                     4.209530                   5.0                1685
# 16                     4.214115                   5.0                7050
# 17                     4.222514                   5.0                3568
# 18                     4.488744                   5.0                 900
# 19                     4.209530                   5.0                1685
# 20                     4.214115                   5.0                7050
# 21                     4.222514                   5.0                3568
# 22                     4.488744                   5.0                 900
# 23                     4.209530                   5.0                1685
# 24                     4.214115                   5.0                7050
# 25                     4.222514                   5.0                3568
# 26                     4.488744                   5.0                 900
# 27                     4.209530                   5.0                1685
# 28                     4.214115                   5.0                7050
# 29                     4.222514                   5.0                3568
# 30                     4.488744                   5.0                 900
# 31                     4.209530                   5.0                1685
# 32                     4.214115                   5.0                7050
# 33                     4.222514                   5.0                3568
# 34                     4.488744                   5.0                 900
# 35                     4.209530                   5.0                1685
# 36                     4.214115                   5.0                7050
# 37                     4.222514                   5.0                3568
# 38                     4.488744                   5.0                 900
# 39                     4.209530                   5.0                1685
#
#     Prozentualer Anteil 5-Sterne Bewertungen  \
# 0                                       0.58
# 1                                       0.55
# 2                                       0.68
# 3                                       0.56
# 4                                       0.58
# 5                                       0.55
# 6                                       0.68
# 7                                       0.56
# 8                                       0.58
# 9                                       0.55
# 10                                      0.68
# 11                                      0.56
# 12                                      0.58
# 13                                      0.55
# 14                                      0.68
# 15                                      0.56
# 16                                      0.58
# 17                                      0.55
# 18                                      0.68
# 19                                      0.56
# 20                                      0.58
# 21                                      0.55
# 22                                      0.68
# 23                                      0.56
# 24                                      0.58
# 25                                      0.55
# 26                                      0.68
# 27                                      0.56
# 28                                      0.58
# 29                                      0.55
# 30                                      0.68
# 31                                      0.56
# 32                                      0.58
# 33                                      0.55
# 34                                      0.68
# 35                                      0.56
# 36                                      0.58
# 37                                      0.55
# 38                                      0.68
# 39                                      0.56
#
#     Prozentualer Anteil 4-Sterne Bewertungen  \
# 0                                       0.21
# 1                                       0.26
# 2                                       0.20
# 3                                       0.23
# 4                                       0.21
# 5                                       0.26
# 6                                       0.20
# 7                                       0.23
# 8                                       0.21
# 9                                       0.26
# 10                                      0.20
# 11                                      0.23
# 12                                      0.21
# 13                                      0.26
# 14                                      0.20
# 15                                      0.23
# 16                                      0.21
# 17                                      0.26
# 18                                      0.20
# 19                                      0.23
# 20                                      0.21
# 21                                      0.26
# 22                                      0.20
# 23                                      0.23
# 24                                      0.21
# 25                                      0.26
# 26                                      0.20
# 27                                      0.23
# 28                                      0.21
# 29                                      0.26
# 30                                      0.20
# 31                                      0.23
# 32                                      0.21
# 33                                      0.26
# 34                                      0.20
# 35                                      0.23
# 36                                      0.21
# 37                                      0.26
# 38                                      0.20
# 39                                      0.23
#
#     Prozentualer Anteil 3-Sterne Bewertungen  \
# 0                                       0.11
# 1                                       0.10
# 2                                       0.08
# 3                                       0.11
# 4                                       0.11
# 5                                       0.10
# 6                                       0.08
# 7                                       0.11
# 8                                       0.11
# 9                                       0.10
# 10                                      0.08
# 11                                      0.11
# 12                                      0.11
# 13                                      0.10
# 14                                      0.08
# 15                                      0.11
# 16                                      0.11
# 17                                      0.10
# 18                                      0.08
# 19                                      0.11
# 20                                      0.11
# 21                                      0.10
# 22                                      0.08
# 23                                      0.11
# 24                                      0.11
# 25                                      0.10
# 26                                      0.08
# 27                                      0.11
# 28                                      0.11
# 29                                      0.10
# 30                                      0.08
# 31                                      0.11
# 32                                      0.11
# 33                                      0.10
# 34                                      0.08
# 35                                      0.11
# 36                                      0.11
# 37                                      0.10
# 38                                      0.08
# 39                                      0.11
#
#     Prozentualer Anteil 2-Sterne Bewertungen  \
# 0                                       0.06
# 1                                       0.05
# 2                                       0.02
# 3                                       0.05
# 4                                       0.06
# 5                                       0.05
# 6                                       0.02
# 7                                       0.05
# 8                                       0.06
# 9                                       0.05
# 10                                      0.02
# 11                                      0.05
# 12                                      0.06
# 13                                      0.05
# 14                                      0.02
# 15                                      0.05
# 16                                      0.06
# 17                                      0.05
# 18                                      0.02
# 19                                      0.05
# 20                                      0.06
# 21                                      0.05
# 22                                      0.02
# 23                                      0.05
# 24                                      0.06
# 25                                      0.05
# 26                                      0.02
# 27                                      0.05
# 28                                      0.06
# 29                                      0.05
# 30                                      0.02
# 31                                      0.05
# 32                                      0.06
# 33                                      0.05
# 34                                      0.02
# 35                                      0.05
# 36                                      0.06
# 37                                      0.05
# 38                                      0.02
# 39                                      0.05
#
#     Prozentualer Anteil 1-Sterne Bewertungen
# 0                                       0.05
# 1                                       0.04
# 2                                       0.02
# 3                                       0.05
# 4                                       0.05
# 5                                       0.04
# 6                                       0.02
# 7                                       0.05
# 8                                       0.05
# 9                                       0.04
# 10                                      0.02
# 11                                      0.05
# 12                                      0.05
# 13                                      0.04
# 14                                      0.02
# 15                                      0.05
# 16                                      0.05
# 17                                      0.04
# 18                                      0.02
# 19                                      0.05
# 20                                      0.05
# 21                                      0.04
# 22                                      0.02
# 23                                      0.05
# 24                                      0.05
# 25                                      0.04
# 26                                      0.02
# 27                                      0.05
# 28                                      0.05
# 29                                      0.04
# 30                                      0.02
# 31                                      0.05
# 32                                      0.05
# 33                                      0.04
# 34                                      0.02
# 35                                      0.05
# 36                                      0.05
# 37                                      0.04
# 38                                      0.02
# 39                                      0.05
